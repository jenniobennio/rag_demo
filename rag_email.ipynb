# %%
from dotenv import load_dotenv
load_dotenv()

from custom_gmail_reader import CustomGmailReader

# Instantiate the CustomGmailReader
loader = CustomGmailReader(
    query="label:INBOX",
    max_results=50,
    results_per_page=10,
    service=None,
)

# Load the emails
documents = loader.load_data()

# Print email information
print(f"Number of documents: {len(documents)}")
for i, doc in enumerate(documents[:20]):
    print(f"Document {i+1}:")
    print(f"To: {doc.metadata.get('to', 'N/A')}")
    print(f"From: {doc.metadata.get('from', 'N/A')}")
    print(f"Subject: {doc.metadata.get('subject', 'N/A')}")
    print(f"Date: {doc.metadata.get('date', 'N/A')}")
    print(f"Content snippet: {doc.text[:1000]}...")
    print("=" * 50)
# Out:
# Number of documents: 50
# Document 1:
# To: jennylkwan@gmail.com
# From: ClassPass <team@info.classpass.com>
# Subject: Your reservation at Love Story Yoga is coming up
# Date: Sun, 22 Sep 2024 21:23:12 +0000 (UTC)
# Content snippet:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Don't forget! A reservation that you booked is coming up. ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
#
#
#
# ClassPass (
# https://ablink.email.classpass.com/ls/click?upn=u001.PidqCXDQ1XYxtlN88uZxCn2sw1uRyofFQNDj5tbXGCa7Fjmd3j67YsfckWyVn4gZcCQvclKqpf2UMGNAM-2FYZKO-2FffHBGJOCxKtaGLzSOjcWASnsEBN2L2EqQ43pIIvZoVRkImlxhBLnSssakZVEWegBHayfxj-2Fh3Iri-2Bhu2JW3ib-2Bjvodf2zuu2YTHS-2FdyuX7OafKiRju6-2FWa4hKH0Pu6V9tmeEY81BvJ8cFMrltrK6HIY23Vhwztbtdy4C5YYhr6fwyA9Ysf0dAc2yG59o3j4jxmC-2BE9-2BtHSQH5Jl57GRnJBeW2c1nWWlSLf6ydMqVptr7qGhRcJlTVeyk1QPu4hQ-3D-3DUQJA_96v19zeXnrBjrsOtYo7-2BEpe148qOqfItNGHsUMrC-2BT-2BGacfucnUlbdYQI8D53FIaB8Pf-2F1sedAOoIleYDvj3Fu8OQ6NvuNR1gwvxFDvB2XKPVFW15OlE4gDcqLWBAQ5L...
# ==================================================
# Document 2:
# To: jennylkwan@gmail.com
# From: Love Story Yoga <hello@lovestoryyoga.com>
# Subject: ClassPass ClassPass reserved Love Flows: Vinyasa at 6:30 PM on 9/22/2024 for you!
# Date: Sun, 22 Sep 2024 21:22:58 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 3:
# To: Jenny Kwan <jennylkwan@gmail.com>
# From: Xing Chen <invitations@linkedin.com>
# Subject: Jenny, please add me to your LinkedIn network
# Date: Sun, 22 Sep 2024 18:38:51 +0000 (UTC)
# Content snippet: Jenny Kwan, respond to Xing’s invite now.
#
# Hi Jenny, I’d like to join your professional network
#
# Xing Chen
# Strategic Investment Manager | Private Financial Advisor
# United States
# Accept:https://www.linkedin.com/comm/mynetwork/invite-accept/invitationId/7243689883628638209/sharedKey/yMeOUeNf/?inviterVanityName=xing-chen-941b527b&lipi=urn%3Ali%3Apage%3Aemail_email_m2m_invite_single_01%3BUt%2FTG1yxTlyVnYoi040OZQ%3D%3D&midToken=AQEgMR-oWOy3HQ&midSig=0Szx8dGFvudbs1&trk=eml-email_m2m_invite_single_01-null-0-null&trkEmail=eml-email_m2m_invite_single_01-null-0-null-null-3gj9pv~m1dx9lx8~e7-null-null&eid=3gj9pv-m1dx9lx8-e7&otpToken=MTAwNTE3ZTExNTJmY2RjMGI3MjQwNGVkNDQxOWU3Yjc4ZmNkZDM0MTk5YTc4ODYxNzdjNDAyNmU0ZjUzNWNmYWY3ZGY4N2I5NDRjN2Q4ZmQ2ZWZmZWE4N2ZlZjRhNTBmZjNkMTA3ODYyNWM2ZTdkZjg1NzUsMSwx
# View profile:https://www.linkedin.com/comm/in/xing-chen-941b527b?lipi=urn%3Ali%3Apage%3Aemail_email_m2m_invite_single_01%3BUt%2FTG1yxTlyVnYoi040OZQ%3D%3D&midToken=AQEgMR-oWOy3HQ&midSig=0Szx8dGFv...
# ==================================================
# Document 4:
# To: jennylkwan@gmail.com
# From: The New York Times <nytdirect@nytimes.com>
# Subject: The Morning: Escape from the front line
# Date: Sun, 22 Sep 2024 11:21:23 +0000
# Content snippet: ...
# ==================================================
# Document 5:
# To: Jenny Kwan <jennylkwan@gmail.com>
# From: True Laurel <noreply@exploretock.com>
# Subject: Your reservation for True Laurel on Tuesday, September 24, 2024, 7:30 PM
# Date: Sat, 21 Sep 2024 22:44:49 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 6:
# To: jennylkwan@gmail.com
# From: La Taqueria <messenger@messaging.squareup.com>
# Subject: Receipt from La Taqueria
# Date: Sat, 21 Sep 2024 20:15:29 +0000
# Content snippet: ...
# ==================================================
# Document 7:
# To: jennylkwan@gmail.com
# From: The New York Times <nytdirect@nytimes.com>
# Subject: The Morning: Fall arrives tomorrow
# Date: Sat, 21 Sep 2024 10:03:30 +0000
# Content snippet: ...
# ==================================================
# Document 8:
# To: jennylkwan@gmail.com
# From: Everlane <noreply@everlane.com>
# Subject: Well…What Do You Think?
# Date: Fri, 20 Sep 2024 21:19:13 +0000
# Content snippet: ...
# ==================================================
# Document 9:
# To: Jenny Kwan <jennylkwan@gmail.com>
# From: Ariel Ruggles <aruggles@throughthehayes.com>
# Subject: Re: RX/Receipt
# Date: Fri, 20 Sep 2024 21:05:00 +0000
# Content snippet: Hey Jenny just wanted to follow up with you and see how the contact trials are doing?
#
# Ariel R.
#
# Through The Hayes Optometry
# 584 Hayes Street, San Francisco CA 94102
# P 415-553-6166
# F 415-874-9470
#
# Warning:   Unauthorized interception or use of this email could be a violation of Federal and State law.  If you have received this email in error, please notify the sender immediately.  This email may contain confidential information belonging to the sender and may be used only for the purpose for which it was requested or intended.  You are responsible for securing any confidential information.  This email may contain health care information.  Permission to use or disclose this information has been granted either by law or the patient.  Further use or disclosure without additional patient authorization or as otherwise permitted by law is prohibited.
#
# ________________________________
# From: Ariel Ruggles <aruggles@throughthehayes.com>
# Sent: Saturday, September 14, 2024 1:12 PM
# T...
# ==================================================
# Document 10:
# To: <jennylkwan@gmail.com>
# From: UnitedHealthcare Notifications <Notifications@edelivery.uhc.com>
# Subject: Now Online: A new claim letter is available
# Date: Fri, 20 Sep 2024 15:02:45 -0600
# Content snippet: United Healthcare
# &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847;
# &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847;
# &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847;
# &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847;
# &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#847; &#84...
# ==================================================
# Document 11:
# To: jennylkwan@gmail.com
# From: Linea Caffe <messenger@messaging.squareup.com>
# Subject: Receipt from Linea Caffe
# Date: Fri, 20 Sep 2024 20:45:06 +0000
# Content snippet: ...
# ==================================================
# Document 12:
# To: jennylkwan@gmail.com
# From: CoffeeShop <messenger@messaging.squareup.com>
# Subject: Receipt from CoffeeShop
# Date: Fri, 20 Sep 2024 20:11:07 +0000
# Content snippet: ...
# ==================================================
# Document 13:
# To: <jennylkwan@gmail.com>
# From: Cafe Du Nord <jarratt@cafedunord.com>
# Subject: TMR: FREE CONCERT: GoldFish, Bag Raiders, and Mykki Blanco @ Union Square
# Date: Fri, 20 Sep 2024 19:03:44 +0000
# Content snippet: Endless Summer in SF
#
# UNION SQUARE PLAZA TAKEOVER
#
# rsvp reminder
#
# SEP 21, 2pm-6pm
#
#
# ** SF Live: GoldFish, Bag Raiders, and Mykki Blanco @ Union Square Plaza (FREE Concert)
# ------------------------------------------------------------
#
# https://www.ticketweb.com/event/sf-live-goldfish-bag-raiders-union-square-plaza-tickets/13723983?pl=cafedunord&REFID=edm24d
# https://www.youtube.com/watch?v=noR8rvqrIMM
#
# BAG RAIDERS
# https://www.youtube.com/watch?v=feA64wXhbjo
#
# one of 2024’s most remixed songs
#
# GOLDFISH
# https://www.youtube.com/watch?v=mgWRdDEGleM
#
# if summer was a sound…
#
# MYKKI BLANCO
# https://www.youtube.com/watch?v=U8VG4anVxjc
#
# Bay Area-raised rapper and performance artist
# Invite your friends! (https://www.ticketweb.com/event/sf-live-goldfish-bag-raiders-union-square-plaza-tickets/13723983?pl=cafedunord&REFID=edm24d)
#
# Want more GoldFish? Come for the afterparty and have an amazing night being up close and personal with the talented duo
#
# https://www.ticketweb....
# ==================================================
# Document 14:
# To: jennylkwan@gmail.com
# From: Luna Billing <billing@getluna.com>
# Subject: Luna Payment Succeeded
# Date: Fri, 20 Sep 2024 14:33:09 +0000
# Content snippet: ...
# ==================================================
# Document 15:
# To: jennylkwan@gmail.com
# From: The New York Times <nytdirect@nytimes.com>
# Subject: The Morning: A rise in breast reductions
# Date: Fri, 20 Sep 2024 10:21:43 +0000
# Content snippet: ...
# ==================================================
# Document 16:
# To: jennylkwan@gmail.com
# From: the castro room <momence@mail.momence.com>
# Subject: Class reminder for Vinyasa | All Levels | Heated
# Date: Fri, 20 Sep 2024 08:01:11 +0000
# Content snippet: ...
# ==================================================
# Document 17:
# To: jennylkwan@gmail.com
# From: ClassPass <team@info.classpass.com>
# Subject: Your reservation at The Castro Room is coming up
# Date: Fri, 20 Sep 2024 06:59:13 +0000 (UTC)
# Content snippet:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Don't forget! A reservation that you booked is coming up. ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌
#
#
#
# ClassPass (
# https://ablink.email.classpass.com/ls/click?upn=u001.PidqCXDQ1XYxtlN88uZxCn2sw1uRyofFQNDj5tbXGCbPYv6QwYPdbQe6vRZp0H2W-2BzMywXqEpVK32qvurKnhDLORC2Dnmzw9W47gp3QjhLMvWnzsKOLV6J67hojbCPwFftAifU6VeO9BKPzmwZ10yvIPRP-2Fi8J9zqL5TlNeMtsrZw86WNbeQv-2BKueH4SjukaqYqEq5LwZSbNHr664FlYkI-2By3ZfSmFQOC5W4n3xRw6sw4JtX5YjRk3zghz33y8WX3F-2B8BB2AjiLPQRo7nj5EOvw4sgqs2gBUBenrRnrtFVSOsIM7zLFtnTJlHLu5O0b2mnflW0IsG0SqTSeQJaquwg-3D-3DGp3p_96v19zeXnrBjrsOtYo7-2BEpe148qOqfItNGHsUMrC-2BT-2BGacfucnUlbdYQI8D53FIaB8Pf-2F1sedAOoIleYDvj3FmXANT13S4LOyuyExWnP9lPApT9Y5-2F4iKPXdTU3Xz4lAy3e0R1...
# ==================================================
# Document 18:
# To: jennylkwan@gmail.com
# From: the castro room <momence@mail.momence.com>
# Subject: You're in! Confirmation for class...
# Date: Fri, 20 Sep 2024 06:58:32 +0000
# Content snippet: ...
# ==================================================
# Document 19:
# To: jennylkwan@gmail.com
# From: Coinbase <no-reply@info.coinbase.com>
# Subject: Please confirm your details to continue trading on Coinbase
# Date: Fri, 20 Sep 2024 00:10:13 +0000
# Content snippet: Hello Jenny,
# Coinbase is committed to working with local regulators around the world. As part of that commitment, we are required by law to periodically confirm and update the personal identifying information of its customers, otherwise known as “Know Your Customer” or “KYC” information, and the time has come for us to refresh your KYC details.
# Confirm Details
# <b>What Happens if I Don't Confirm My&nbsp;Details?</b><br>
# 												   If you do not complete the KYC refresh process by 2024-10-13, we are required by law to restrict your account.  This means that you will no longer be able to deposit or trade cryptocurrencies on Coinbase until we can update your KYC information. Any open orders will also be canceled.
# <b>How to Confirm your Details</b>
# 												   <br>Completing the refresh is simple and should take about a minute:
# 												   <ul style="line-height:1.5;mso-line-height-alt:24px;font-size:16px">
# 												       <li><span style="font-size:16px;">
# 											...
# ==================================================
# Document 20:
# To: jennylkwan@gmail.com
# From: Wells Fargo <alerts@notify.wellsfargo.com>
# Subject: We're updating the Wells Fargo Online Access Agreement
# Date: Thu, 19 Sep 2024 16:02:46 -0700 (PDT)
# Content snippet: ...
# ==================================================

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core import Settings
from llama_index.core.callbacks import CallbackManager
from langfuse.llama_index import LlamaIndexCallbackHandler
 
load_dotenv()
langfuse_callback_handler = LlamaIndexCallbackHandler()
Settings.callback_manager = CallbackManager([langfuse_callback_handler])

# Create index
index = VectorStoreIndex.from_documents(documents)

# Create retriever
retriever = VectorIndexRetriever(index=index)

# Create query engine
query_engine = RetrieverQueryEngine(retriever=retriever)

# Example query
response = query_engine.query("What all upcoming events do I have? Can you list multiple events")
print(response)
# Out:
# Item exceeds size limit (size: 1246145), dropping input / output / metadata of item until it fits.
# Monolink, I Hate Models, DJ DIESEL, and deadmau5 are some of the upcoming events mentioned in the emails.
